# %%
import pandas as pd
import matplotlib.pyplot as plt
from pyecharts.charts import Bar, Line
import pyecharts.options as opts

# %%
data = pd.read_csv('/Users/hukeer/Desktop/上海楼房.csv')
data = data[data['价格'].str.match('^[0-9]+$')]
quyu =  ['黄浦','杨浦','虹口','普陀','静安','浦东','闵行','松江','宝山','青浦','嘉定','奉贤','崇明','金山']
data = data[data['位置'].isin(quyu)]
data['价格'] = data['价格'].astype('float')
result = data.groupby(by='位置')['价格'].mean()
result.sort_values(ascending=False, inplace=True)
x = result.index
y = result.values

# %%
num = data['位置'].value_counts()
sortlist = list(x)
num_new = num[sortlist]
bar = (
    Bar()
    .add_xaxis(list(x))
    .add_yaxis('各区均价', list(y), yaxis_index=0) 
    .extend_axis(yaxis=opts.AxisOpts(name='楼盘数'))
)

line = (
    Line()
    .add_xaxis(list(x))
    .add_yaxis('楼盘数', list(num_new), yaxis_index=1, z=2)    
)
bar.overlap(line).render_notebook()
# bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4246073419e54fa0be12fdb2bef32ffa" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4246073419e54fa0be12fdb2bef32ffa = echarts.init(
#                     document.getElementById('4246073419e54fa0be12fdb2bef32ffa'), 'white', {renderer: 'canvas'});
#                 var option_4246073419e54fa0be12fdb2bef32ffa = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5404\u533a\u5747\u4ef7",
#             "yAxisIndex": 0,
#             "legendHoverLink": true,
#             "data": [
#                 155500.0,
#                 117333.33333333333,
#                 75666.66666666667,
#                 63183.46153846154,
#                 61928.57142857143,
#                 61777.77777777778,
#                 48976.166666666664,
#                 38875.0,
#                 30416.5,
#                 30000.0,
#                 23441.545454545456
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u697c\u76d8\u6570",
#             "connectNulls": false,
#             "yAxisIndex": 1,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u8679\u53e3",
#                     2
#                 ],
#                 [
#                     "\u666e\u9640",
#                     3
#                 ],
#                 [
#                     "\u95f5\u884c",
#                     9
#                 ],
#                 [
#                     "\u6d66\u4e1c",
#                     13
#                 ],
#                 [
#                     "\u9752\u6d66",
#                     7
#                 ],
#                 [
#                     "\u677e\u6c5f",
#                     9
#                 ],
#                 [
#                     "\u5b9d\u5c71",
#                     6
#                 ],
#                 [
#                     "\u5609\u5b9a",
#                     4
#                 ],
#                 [
#                     "\u5d07\u660e",
#                     6
#                 ],
#                 [
#                     "\u5949\u8d24",
#                     3
#                 ],
#                 [
#                     "\u91d1\u5c71",
#                     11
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 2
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5404\u533a\u5747\u4ef7",
#                 "\u697c\u76d8\u6570"
#             ],
#             "selected": {
#                 "\u5404\u533a\u5747\u4ef7": true,
#                 "\u697c\u76d8\u6570": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u8679\u53e3",
#                 "\u666e\u9640",
#                 "\u95f5\u884c",
#                 "\u6d66\u4e1c",
#                 "\u9752\u6d66",
#                 "\u677e\u6c5f",
#                 "\u5b9d\u5c71",
#                 "\u5609\u5b9a",
#                 "\u5d07\u660e",
#                 "\u5949\u8d24",
#                 "\u91d1\u5c71"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         },
#         {
#             "name": "\u697c\u76d8\u6570",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_4246073419e54fa0be12fdb2bef32ffa.setOption(option_4246073419e54fa0be12fdb2bef32ffa);
#         });
#     </script>

# %% [markdown]
# # 美化图表 opts
# ### set_global_options
# - $TitleOpts$: 标题配置项
# - $LegendOpts$: 图例配置项
# - $ToolboxOpts$: 工具箱配置项
# - $VisualMapOpts$: 视觉映射配置项
# - $TooltipOpts$: 提示框配置项
# - $DataZoomOpts$: 区域缩放配置项

# %%
num = data['位置'].value_counts()
sortlist = list(x)
num_new = num[sortlist]
bar = (
    Bar()
    .add_xaxis(list(x))
    .add_yaxis('各区均价', list(y), yaxis_index=0) 
    .extend_axis(yaxis=opts.AxisOpts(name='楼盘数'))
    .set_global_opts(
        title_opts = opts.TitleOpts(title='房价和楼盘数'),
        datazoom_opts = opts.DataZoomOpts(is_show=True),
        toolbox_opts = opts.ToolboxOpts(),
        tooltip_opts = opts.TooltipOpts(trigger='axis',axis_pointer_type= 'cross')
    )
)

line = (
    Line()
    .add_xaxis(list(x))
    .add_yaxis('楼盘数', list(num_new), yaxis_index=1, z=2)    
)
bar.render('/Users/hukeer/Desktop/bar.html')
bar.overlap(line).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d0c04bd7820b4dc99c1b590f3709cdca" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d0c04bd7820b4dc99c1b590f3709cdca = echarts.init(
#                     document.getElementById('d0c04bd7820b4dc99c1b590f3709cdca'), 'white', {renderer: 'canvas'});
#                 var option_d0c04bd7820b4dc99c1b590f3709cdca = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5404\u533a\u5747\u4ef7",
#             "yAxisIndex": 0,
#             "legendHoverLink": true,
#             "data": [
#                 155500.0,
#                 117333.33333333333,
#                 75666.66666666667,
#                 63183.46153846154,
#                 61928.57142857143,
#                 61777.77777777778,
#                 48976.166666666664,
#                 38875.0,
#                 30416.5,
#                 30000.0,
#                 23441.545454545456
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u697c\u76d8\u6570",
#             "connectNulls": false,
#             "yAxisIndex": 1,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u8679\u53e3",
#                     2
#                 ],
#                 [
#                     "\u666e\u9640",
#                     3
#                 ],
#                 [
#                     "\u95f5\u884c",
#                     9
#                 ],
#                 [
#                     "\u6d66\u4e1c",
#                     13
#                 ],
#                 [
#                     "\u9752\u6d66",
#                     7
#                 ],
#                 [
#                     "\u677e\u6c5f",
#                     9
#                 ],
#                 [
#                     "\u5b9d\u5c71",
#                     6
#                 ],
#                 [
#                     "\u5609\u5b9a",
#                     4
#                 ],
#                 [
#                     "\u5d07\u660e",
#                     6
#                 ],
#                 [
#                     "\u5949\u8d24",
#                     3
#                 ],
#                 [
#                     "\u91d1\u5c71",
#                     11
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 2
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5404\u533a\u5747\u4ef7",
#                 "\u697c\u76d8\u6570"
#             ],
#             "selected": {
#                 "\u5404\u533a\u5747\u4ef7": true,
#                 "\u697c\u76d8\u6570": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "axis",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "cross"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u8679\u53e3",
#                 "\u666e\u9640",
#                 "\u95f5\u884c",
#                 "\u6d66\u4e1c",
#                 "\u9752\u6d66",
#                 "\u677e\u6c5f",
#                 "\u5b9d\u5c71",
#                 "\u5609\u5b9a",
#                 "\u5d07\u660e",
#                 "\u5949\u8d24",
#                 "\u91d1\u5c71"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         },
#         {
#             "name": "\u697c\u76d8\u6570",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u623f\u4ef7\u548c\u697c\u76d8\u6570",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "horizontal",
#         "itemSize": 15,
#         "itemGap": 10,
#         "left": "80%",
#         "feature": {
#             "saveAsImage": {
#                 "type": "png",
#                 "backgroundColor": "auto",
#                 "connectedBackgroundColor": "#fff",
#                 "show": true,
#                 "title": "\u4fdd\u5b58\u4e3a\u56fe\u7247",
#                 "pixelRatio": 1
#             },
#             "restore": {
#                 "show": true,
#                 "title": "\u8fd8\u539f"
#             },
#             "dataView": {
#                 "show": true,
#                 "title":

# %%
from pyecharts.charts import Map
map1 = (
    Map()
    .add('房价均价', [(i+'区',j) for i,j in zip(list(x),list(y))],'上海')
    .set_global_opts(
        visualmap_opts= opts.VisualMapOpts(min_= y.min(),max_=y.max())
    )
)
map1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '上海':'https://assets.pyecharts.org/assets/maps/shanghai'
#         }
#     });
# </script>
#
#         <div id="bc7f23d8d44f448381089ced2124379c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '上海'], function(echarts) {
#                 var chart_bc7f23d8d44f448381089ced2124379c = echarts.init(
#                     document.getElementById('bc7f23d8d44f448381089ced2124379c'), 'white', {renderer: 'canvas'});
#                 var option_bc7f23d8d44f448381089ced2124379c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u623f\u4ef7\u5747\u4ef7",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "\u4e0a\u6d77",
#             "data": [
#                 {
#                     "name": "\u8679\u53e3\u533a",
#                     "value": 155500.0
#                 },
#                 {
#                     "name": "\u666e\u9640\u533a",
#                     "value": 117333.33333333333
#                 },
#                 {
#                     "name": "\u95f5\u884c\u533a",
#                     "value": 75666.66666666667
#                 },
#                 {
#                     "name": "\u6d66\u4e1c\u533a",
#                     "value": 63183.46153846154
#                 },
#                 {
#                     "name": "\u9752\u6d66\u533a",
#                     "value": 61928.57142857143
#                 },
#                 {
#                     "name": "\u677e\u6c5f\u533a",
#                     "value": 61777.77777777778
#                 },
#                 {
#                     "name": "\u5b9d\u5c71\u533a",
#                     "value": 48976.166666666664
#                 },
#                 {
#                     "name": "\u5609\u5b9a\u533a",
#                     "value": 38875.0
#                 },
#                 {
#                     "name": "\u5d07\u660e\u533a",
#                     "value": 30416.5
#                 },
#                 {
#                     "name": "\u5949\u8d24\u533a",
#                     "value": 30000.0
#                 },
#                 {
#                     "name": "\u91d1\u5c71\u533a",
#                     "value": 23441.545454545456
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u623f\u4ef7\u5747\u4ef7"
#             ],
#             "selected": {
#                 "\u623f\u4ef7\u5747\u4ef7": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 23441.545454545456,
#         "max": 155500.0,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_bc7f23d8d44f448381089ced2124379c.setOption(option_bc7f23d8d44f448381089ced2124379c);
#         });
#     </script>
