# %%
import requests
from lxml import etree
import pandas as pd

# %%
url = 'https://movie.douban.com/subject/1889243/comments?status=P'
headers ={ 'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.81 Safari/537.36'}
res = requests.get(url, headers=headers)
res
# Out:
# <Response [200]>

# %%
txt = res.text

# %%
dom = etree.HTML(txt)
names = dom.xpath('//span[@class="comment-info"]/a/text()')
ratings = dom.xpath('//span[@class="comment-info"]/span[starts-with(@class,"allstar")]/@class')
#或者
#ratings = dom.xpath('//span[@class="comment-info"]/span[2]/@class')

#class值中有空格。
times = dom.xpath('//span[@class="comment-info"]/span[@class="comment-time "]/@title')
#这里第二个//代表子孙节点即可
message = dom.xpath('//div[@class="comment"]//span[@class="short"]/text()')
user_url= dom.xpath('//span[@class="comment-info"]/a/@href') #用户名的超链接
votes = dom.xpath('//div[@class="comment"]//span[@class="votes vote-count"]/text()')

# %%
print(names)
print(ratings)
print(times)
print(message)
print(user_url)
print(votes)
# Out:
# ['一只野生叮当猫', '比岁月含蓄', '同志亦凡人中文站', '影志', 'CSUMMERY', '我怀念的', '喵喵猫', '桃桃林林', '大夫唐', '浣熊市垃圾回收', 'Panda的影音', '芦哲峰', '舌在足矣', '朝暮雪', '周杰伧的小粉丝', '张小北', '猴猴', '阿拉莫没有猫', 'KAPO', 'Fantasy']
# ['allstar50 rating', 'allstar50 rating', 'allstar40 rating', 'allstar50 rating', 'allstar50 rating', 'allstar50 rating', 'allstar50 rating', 'allstar40 rating', 'allstar50 rating', 'allstar50 rating', 'allstar50 rating', 'allstar50 rating', 'allstar50 rating', 'allstar50 rating', 'allstar50 rating', 'allstar50 rating', 'allstar10 rating', 'allstar50 rating', 'allstar50 rating', 'allstar50 rating']
# ['2014-11-11 00:03:39', '2014-11-06 23:27:12', '2014-11-06 09:58:26', '2014-11-12 10:28:53', '2014-11-06 22:17:10', '2014-11-06 21:46:54', '2014-11-07 00:46:33', '2014-11-12 17:28:55', '2014-11-12 17:14:29', '2014-11-06 20:22:49', '2014-11-07 00:48:01', '2014-11-12 23:33:42', '2014-11-05 20:11:39', '2014-11-17 22:13:29', '2014-11-16 10:06:40', '2014-11-13 00:16:46', '2014-11-08 13:04:51', '2014-11-07 14:35:50', '2014-11-06 16:13:19', '2014-11-08 05:59:44']
# ['诺兰说：如果我活得够长 那么豆瓣TOP250就被我承包了。', '时间可以伸缩和折叠，唯独不能倒退。你的鹤发或许是我的童颜，而我一次呼吸能抵过你此生的岁月。', '以地球全部北京化（咦？）为背景的近未来硬科幻，对虫洞、重力和时间维度都有新颖的理解，刻画的浩瀚宇宙让人目眩。可惜诺兰的野心太大（真的是bigger than bigger！），而且把人性拔那么高，到最后就成太空神棍片了...', "太壮阔了，无以言表！40'渐入佳境，80'叹为观止，120'泪流满面，160'恍如隔世…不曾如此贴近浩瀚星空，被它环抱；不曾如此触摸生命之弦，遁入五维幻境。瑕不掩瑜的科幻神作，刷新视觉的IMAX体验，观影前撒好尿，准备接受近三小时的泪腺洗礼。“爱是一种力量，让我们超越时空感知它的存在”-发自豆瓣App", '我想给100颗星，这可能是我至今看过最令我震撼的电影了。到电影结束时候还不断流泪，奇迹不是因为有上帝 也不是有什么不可知的 某种力量，正是我们自己，人类不相信人类的力量把那些我们无可预
女娲嘛。', '诺兰的科幻片其实和传统意义上的「科幻片」不是一个体系。', '二刷极烂，没一点好', '看哭了，哭的非常惨，从没想过一部电影能给我带来这样可怕的震撼；现在看完已经两个小时了，但深深印在脑海里的那些元素：诺兰的技巧，马修的演技，季默的配乐，以及亲情的最终命题，都让我的心脏又回到观影时的那种几乎炸裂的感觉。我觉得要很长时间才能缓过来了。', '一个好geek是多么提高人类幸福度的存在：会写好剧本，会挑好演员，音乐品味也好。。一个好geek和一个好导演的合体。。于是有了这个野心勃勃主题里有细细密密的亲情的抓马科幻片。。只是小阿弗莱克和达蒙那两个设置也太鸡肋而且不讨喜了吧！（还是要打五星！', '世界上最遥远的距离，不是天涯海角，也不是生离死别，而是我就站在你书架的背后看着你成长老去，却只能孤独地玩着沙子和摩斯密码，顺便长生不老。']
# ['https://www.douban.com/people/62654988/', 'https://www.douban.com/people/44290578/', 'https://www.douban.com/people/3540441/', 'https://www.douban.com/people/tjz230/', 'https://www.douban.com/people/cxyshang/', 'https://www.douban.com/people/nocturnelee/', 'https://www.douban.com/people/1491623/', 'https://www.douban.com/people/qijiuzhiyue/', 'https://www.douban.com/people/66738259/', 'https://www.douban.com/people/crankysophia/', 'https://www.douban.com/people/PandaMovieMusic/', 'https://www.douban.com/people/luhua/', 'https://www.douban.com/people/shezaizuyi/', 'https://www.douban.com/people/lingrui1995/', 'https://www.douban.com/people/54883420/', 'https://www.douban.com/people/xzfd/', 'https://www.douban.com/people/E-Yum/', 'https://www.douban.com/people/61712114/', 'https://www.douban.com/people/kapocyj/', 'https://www.douban.com/people/FantasyDuan/']
# ['43865', '32915', '3338', '19418', '17796', '7405', '6251', '2145', '6008', '4243', '2529', '2440', '2480', '1138', '953', '986', '353', '916', '684', '670']

# %%
print(len(names))
print(len(ratings))
print(len(times))
print(len(message))
print(len(user_url))
print(len(votes))
# Out:
# 20
# 20
# 20
# 20
# 20
# 20

# %%
import random
import time
cities = []
load_times = []
j = 0
for i in user_url:
    print(f'正在爬取第{j}页')
    j +=1 
    web_data = requests.get(i, headers=headers)
    dom_url = etree.HTML(web_data.text)
    #为了保险起见，可以把div的上级div也写上
    address = dom_url.xpath('//div[@class="basic-info"]//div[@class="user-info"]/a/text()')
    load_time = dom_url.xpath('//div[@class="basic-info"]//div[@class="user-info"]/div[@class="pl"]/text()')
    cities.append(address)
    load_times.append(load_time)
    time.sleep(random.randint(2,4))
# Out:
# 正在爬取第0页
# 正在爬取第1页
# 正在爬取第2页
# 正在爬取第3页
# 正在爬取第4页
# 正在爬取第5页
# 正在爬取第6页
# 正在爬取第7页
# 正在爬取第8页
# 正在爬取第9页
# 正在爬取第10页
# 正在爬取第11页
# 正在爬取第12页
# 正在爬取第13页
# 正在爬取第14页
# 正在爬取第15页
# 正在爬取第16页
# 正在爬取第17页
# 正在爬取第18页
# 正在爬取第19页

# %%
print(names)
print(ratings)
print(times)
print(message)
print(user_url)
print(votes)
# ['https://www.douban.com/people/62654988/', 'https://www.douban.com/people/44290578/', 'https://www.douban.com/people/3540441/', 'https://www.douban.com/people/tjz230/', 'https://www.douban.com/people/cxyshang/', 'https://www.douban.com/people/nocturnelee/', 'https://www.douban.com/people/1491623/', 'https://www.douban.com/people/qijiuzhiyue/', 'https://www.douban.com/people/66738259/', 'https://www.douban.com/people/crankysophia/', 'https://www.douban.com/people/PandaMovieMusic/', 'https://www.douban.com/people/luhua/', 'https://www.douban.com/people/shezaizuyi/', 'https://www.douban.com/people/lingrui1995/', 'https://www.douban.com/people/54883420/', 'https://www.douban.com/people/xzfd/', 'https://www.douban.com/people/E-Yum/', 'https://www.douban.com/people/61712114/', 'https://www.douban.com/people/kapocyj/', 'https://www.douban.com/people/FantasyDuan/']
# ['43865', '32915', '3338', '19418', '17796', '7405', '6251', '2145', '6008', '4243', '2529', '2440', '2480', '1138', '953', '986', '353', '916', '684', '670']
# [['上海'], ['中国香港'], [], ['北京'], ['Seoul (Sŏul), South Korea'], ['中国香港'], ['北京'], ["P'yŏngyang, North Korea"], ['陕西西安'], ['Roma, Italy'], ['福建泉州'], ['辽宁沈阳'], ['New York City, United States'], ['四川成都'], ['北京'], ['北京'], ['Los Angeles, United States'], ['New York City, United States'], ['Berlin, Germany'], ['San Francisco Bay Area, United States']]
# [['62654988 ', ' 2012-06-28加入'], ['44290578 ', ' 2010-08-03加入'], ['3540441 ', ' 2009-01-25加入'], ['tjz230 ', ' 2005-07-18加入'], ['cxyshang ', ' 2010-12-30加入'], ['nocturnelee ', ' 2008-02-04加入'], ['1491623 ', ' 2007-04-02加入'], ['qijiuzhiyue ', ' 2005-10-09加入'], ['66738259 ', ' 2012-11-30加入'], ['crankysophia ', ' 2010-02-19加入'], ['PandaMovieMusic ', ' 2011-08-01加入'], ['luhua ', ' 2006-11-27加入'], ['shezaizuyi ', ' 2010-08-17加入'], ['lingrui1995 ', ' 2012-08-07加入'], ['54883420 ', ' 2011-10-07加入'], ['xzfd ', ' 2008-03-04加入'], ['E-Yum ', ' 2007-12-01加入'], ['61712114 ', ' 2012-05-26加入'], ['kapocyj ', ' 2009-10-02加入'], ['FantasyDuan ', ' 2008-11-03加入']]

# %%
print(len(names))
print(len(ratings))
print(len(times))
print(len(message))
print(len(user_url))
print(len(votes))
print(len(cities))
print(len(load_times))
# Out:
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20

# %%
import re
ratings_n = ['' if 'rating' not in i else int(re.findall('[0-9]+', i)[0]) for i in ratings] #也可以re.findall('\d{2}', i)
cities_n = ['' if i == [] else i[0] for i in cities]
load_times_n = ['' if i == [] else i[1][:-2].strip(' ') for i in load_times]

# %%
#构建数据框
data = pd.DataFrame({
    '用户名': names,
    '居住城市': cities_n,
    '加入时间': load_times_n,
    '评分': ratings_n,
    '发表时间': times,
    '短评正文': message,
    '赞同数量': votes
})
data
# Out:
#          用户名                                   居住城市        加入时间  评分  \
# 13  2014-11-17 22:13:29  对我们来说二维空间就是一张纸，从纸的一端走到另一端最快的方式是把它折起来。\n对五维生物来说...
# 14  2014-11-16 10:06:40                                安妮海瑟薇最后变成了谁？对了，女娲嘛。
# 15  2014-11-13 00:16:46                        诺兰的科幻片其实和传统意义上的「科幻片」不是一个体系。
# 16  2014-11-08 13:04:51                                          二刷极烂，没一点好
# 17  2014-11-07 14:35:50  看哭了，哭的非常惨，从没想过一部电影能给我带来这样可怕的震撼；现在看完已经两个小时了，但深深...
# 18  2014-11-06 16:13:19  一个好geek是多么提高人类幸福度的存在：会写好剧本，会挑好演员，音乐品味也好。。一个好ge...
# 19  2014-11-08 05:59:44  世界上最遥远的距离，不是天涯海角，也不是生离死别，而是我就站在你书架的背后看着你成长老去，却...
#
#      赞同数量
# 0   43865
# 1   32915
# 2    3338
# 3   19418
# 4   17796
# 5    7405
# 6    6251
# 7    2145
# 8    6008
# 9    4243
# 10   2529
# 11   2440
# 12   2480
# 13   1138
# 14    953
# 15    986
# 16    353
# 17    916
# 18    684
# 19    670

# %%
def myfunc(txt)
    dom = etree.HTML(txt)
    names = dom.xpath('//span[@class="comment-info"]/a/text()')
    ratings = dom.xpath('//span[@class="comment-info"]/span[starts-with(@class,"allstar")]/@class')
    #或者
    #ratings = dom.xpath('//span[@class="comment-info"]/span[2]/@class')

    #class值中有空格。
    times = dom.xpath('//span[@class="comment-info"]/span[@class="comment-time "]/@title')
    #这里第二个//代表子孙节点即可
    message = dom.xpath('//div[@class="comment"]//span[@class="short"]/text()')
    user_url= dom.xpath('//span[@class="comment-info"]/a/@href') #用户名的超链接
    votes = dom.xpath('//div[@class="comment"]//span[@class="votes vote-count"]/text()')

    cities = []
    load_times = []
    j = 0
    for i in user_url:
        print(f'正在爬取第{j}页')
        j +=1 
        web_data = requests.get(i, headers=headers)
        dom_url = etree.HTML(web_data.text)
        #为了保险起见，可以把div的上级div也写上
        address = dom_url.xpath('//div[@class="basic-info"]//div[@class="user-info"]/a/text()')
        load_time = dom_url.xpath('//div[@class="basic-info"]//div[@class="user-info"]/div[@class="pl"]/text()')
        cities.append(address)
        load_times.append(load_time)
        time.sleep(random.randint(2,4))

    ratings_n = ['' if 'rating' not in i else int(re.findall('[0-9]+', i)[0]) for i in ratings] #也可以re.findall('\d{2}', i)
    cities_n = ['' if i == [] else i[0] for i in cities]
    load_times_n = ['' if i == [] else i[1][:-2].strip(' ') for i in load_times]

    data = pd.DataFrame({
        '用户名': names,
        '居住城市': cities_n,
        '加入时间': load_times_n,
        '评分': ratings_n,
        '发表时间': times,
        '短评正文': message,
        '赞同数量': votes
    })
    return data

# %%
all_data = pd.DataFrame()
for pg in range(0,480,20):
    url = 'https://movie.douban.com/subject/1889243/comments?start={}&limit=20&status=P&sort=new_score'.format(pg)
    res = requests.get(url, headers=headers)
    data = myfuync(res.text)
    all_data = pd.concat([all_data, data],axis=0)
all_data
